# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import requests as req
import re
import pandas as pd
from html_table_parser import parser_functions
import os

# %%
import os

def save_hir_file(*args, ):
    print(args[:])
    if len(args) == 1:
        return args[0]
    dirname = "/".join(args[:])
    os.makedirs(dirname, exist_ok = False)
    return "/".join(args)

# %% [markdown]
# #### KBO 와일드카드 참여팀(타자 and 투수) // 2017 ~ 2023

# %%
path = "C://Users//nhw85//Downloads//chromedriver_win32//chromedriver.exe"

driver = webdriver.Chrome(path)

Hitter_year =  {36 : "2017", 37 : "2018", 38 : "2019", 39 : "2020", 40 : "2021", 41 : "2022", 42 : "2023"}
Pitcher_year = {36 : "2017", 37 : "2018", 38 : "2019", 39 : "2020", 40 : "2021", 41 : "2022", 42 : "2023"}
Defense_year = [17, 18, 19, 20, 21, 22, 23]
Runner_year = [17, 18, 19, 20, 21, 22, 23]
team = {2:"두산", 3:"롯데", 4: "삼성", 5: "키움", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10:"NC", 11:"SK" }
# 

category_list = ['HitterBasic/Basic1.aspx', 'PitcherBasic/Basic1.aspx', 
                 'Defense/Basic.aspx', 'Runner/Basic.aspx']

driver.get('https://www.koreabaseball.com/Record/Player/PitcherBasic/Basic1.aspx')

for X,Y in enumerate(Hitter_year):
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeason_ddlSeason"]/option[{}]'.format(Y)).click() # 연도
    time.sleep(0.5)
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeries_ddlSeries"]/option[3]').click() # 와일드카드
    time.sleep(0.5)
    for Z,T in enumerate(team): 
        driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click()
        time.sleep(1.5)
    
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        data = soup.find('table', { 'class': 'tData01 tt' })
    
        # 크롤링
    
        table1 = parser_functions.make2d(data)

        df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
        if df1.empty:
            pass
        else:
            # print(df1)
            df1.to_csv('{}'.format(Hitter_year[Y]) +'_'+'{}'.format(team[T]) +'_'+'와일드카드 선수기록(투수).csv', encoding = 'utf-8')

    

        # df1.to_csv('{}'.format(X) +'_'+'선수세부기록(타자).csv', encoding = 'utf-8')
# Out:
# C:\Users\nhw85\AppData\Local\Temp\ipykernel_141308\2747565567.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %% [markdown]
# #### KBO 준플레이오프

# %%
path = "C://Users//nhw85//Downloads//chromedriver_win32//chromedriver.exe"

driver = webdriver.Chrome(path)

year = {36 : "2017", 37 : "2018", 38 : "2019", 39 : "2020", 40 : "2021", 41 : "2022", 42 : "2023"}
team = {2: "넥센", 3:"두산", 4: "롯데", 5: "삼성", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
Defense_year = [17, 18, 19, 20, 21, 22, 23]
Runner_year = [17, 18, 19, 20, 21, 22, 23]
# 

category_list = ['HitterBasic/Basic1.aspx', 'PitcherBasic/Basic1.aspx', 
                 'Defense/Basic.aspx', 'Runner/Basic.aspx']

driver.get('https://www.koreabaseball.com/Record/Player/HitterBasic/Basic1.aspx')

for X,Y in enumerate(Hitter_year):
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeason_ddlSeason"]/option[{}]'.format(Y)).click() # 연도
    time.sleep(0.5)
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeries_ddlSeries"]/option[4]').click() # 준플레이오프
    time.sleep(0.5)
    for Z,T in enumerate(team): 
        driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click()
        time.sleep(1.5)
    
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        data = soup.find('table', { 'class': 'tData01 tt' })
    
        # 크롤링
    
        table1 = parser_functions.make2d(data)

        df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
        if df1.empty:
            pass
        else:
            # print(df1)
            df1.to_csv('{}'.format(Hitter_year[Y]) +'_'+'{}'.format(team[T]) +'_'+'준플레이오프 선수기록(투수).csv', encoding = 'utf-8')
# Out:
# C:\Users\nhw85\AppData\Local\Temp\ipykernel_141308\3832196222.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %% [markdown]
# #### KBO 정규시즌(투수)

# %%
path = "C://Users//nhw85//Downloads//chromedriver_win32//chromedriver.exe"

driver = webdriver.Chrome(path)

year = {36 : "2017", 37 : "2018", 38 : "2019", 39 : "2020", 40 : "2021", 41 : "2022", 42 : "2023"}
team_1 = {2:"넥센", 3:"두산", 4: "롯데", 5: "삼성", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
team_2 = {2:"두산", 3:"롯데", 4: "삼성", 5: "키움", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
team_3 = {2:"두산", 3:"롯데", 4: "삼성", 5: "키움", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SSG" }
season = {1: "정규시즌", 2: "시범경기", 3: "와일드카드", 4: "준플레이오프", 5: "플레이오프", 6: "한국시리즈"}


category_list = ['HitterBasic/Basic1.aspx', 'PitcherBasic/Basic1.aspx', 
                'Defense/Basic.aspx', 'Runner/Basic.aspx']

driver.get('https://www.koreabaseball.com/Record/Player/PitcherBasic/Detail2.aspx')

for Y in year:
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeason_ddlSeason"]/option[{}]'.format(Y)).click() # 연도
    time.sleep(1)
    # season
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeries_ddlSeries"]/option[1]').click() # Season
    time.sleep(1)
    if year[Y] in ["2017", "2018"]:
        for T in team_1: 
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
            time.sleep(1.3)

            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            data = soup.find('table', { 'class': 'tData01 tt' })

            # 크롤링

            table1 = parser_functions.make2d(data)

            df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
            if df1.empty:
                pass
            else:
                # print(df1)
                df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team_1[T]) +'_' + '선수세부기록_2(투수).csv', encoding = 'utf-8')
    elif year[Y] in ["2019", "2020"]:
        for T in team_2: 
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
            time.sleep(1.3)

            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            data = soup.find('table', { 'class': 'tData01 tt' })

            # 크롤링

            table1 = parser_functions.make2d(data)

            df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
            if df1.empty:
                pass
            else:
                # print(df1)
                df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team_2[T]) +'_' + '선수세부기록_2(투수).csv', encoding = 'utf-8')
    elif year[Y] in ["2021", "2022", "2023"]:
        for T in team_3: 
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
            time.sleep(1.3)

            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            data = soup.find('table', { 'class': 'tData01 tt' })

            # 크롤링

            table1 = parser_functions.make2d(data)

            df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
            if df1.empty:
                pass
            else:
                # print(df1)
                df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team_3[T]) +'_' + '선수세부기록_2(투수).csv', encoding = 'utf-8')
# Out:
# C:\Users\nhw85\AppData\Local\Temp\ipykernel_69772\2689935459.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %% [markdown]
# #### KBO 연간_정규시즌_팀별_포지션별_월별(타자)

# %%
path = "C://Users//nhw85//Downloads//chromedriver_win32//chromedriver.exe"

driver = webdriver.Chrome(path)

year = {36 : "2017", 37 : "2018", 38 : "2019", 39 : "2020", 40 : "2021", 41 : "2022", 42 : "2023"}
team_1 = {2:"넥센", 3:"두산", 4: "롯데", 5: "삼성", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
team_2 = {2:"두산", 3:"롯데", 4: "삼성", 5: "키움", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
team_3 = {2:"두산", 3:"롯데", 4: "삼성", 5: "키움", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SSG" }
season = {1: "정규시즌", 2: "시범경기", 3: "와일드카드", 4: "준플레이오프", 5: "플레이오프", 6: "한국시리즈"}
position = {2: "포수", 3: "내야수", 4: "외야수"}
situation = 2 # 월별
detail = {2: "3~4월", 3: "5월", 4: "6월", 5: "7월", 6: "8월", 7: "9월이상" }



category_list = ['HitterBasic/Basic1.aspx', 'PitcherBasic/Basic1.aspx', 
                'Defense/Basic.aspx', 'Runner/Basic.aspx']

driver.get('https://www.koreabaseball.com/Record/Player/HitterBasic/Basic1.aspx')

for Y in year:
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeason_ddlSeason"]/option[{}]'.format(Y)).click() # 연도
    time.sleep(1)
    # season
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeries_ddlSeries"]/option[1]').click() # Season
    time.sleep(1)
    if year[Y] in ["2017", "2018"]:
        for T in team_1: 
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
            time.sleep(1.3)
            for P in position:
                driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlPos_ddlPos"]/option[{}]'.format(P)).click() # 포지션별
                time.sleep(1.5)
                # 월별
                driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituation_ddlSituation"]/option[2]').click() # 상황별 1
                time.sleep(1.5)
                for D in detail:
                    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail"]/option[{}]'.format(D)).click()
                    time.sleep(1.5)

                    html = driver.page_source
                    soup = BeautifulSoup(html, 'html.parser')
                    data = soup.find('table', { 'class': 'tData01 tt' })
        
                    # 크롤링
        
                    table1 = parser_functions.make2d(data)

                    df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
                    if df1.empty:
                        pass
                    else:
                        # print(df1)
                        df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team_1[T]) +'_'+ '월별' +'_'+ '{}'.format(position[P]) +'_'+'{}'.format(detail[D]) + '선수기록.csv', encoding = 'utf-8')
    elif year[Y] in ["2019", "2020"]:
        for T in team_2: 
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
            time.sleep(1.3)
            for P in position:
                driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlPos_ddlPos"]/option[{}]'.format(P)).click() # 포지션별
                time.sleep(1.5)
                # 월별
                driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituation_ddlSituation"]/option[2]').click() # 상황별 1
                time.sleep(1.5)
                for D in detail:
                    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail"]/option[{}]'.format(D)).click()
                    time.sleep(1.5)

                    html = driver.page_source
                    soup = BeautifulSoup(html, 'html.parser')
                    data = soup.find('table', { 'class': 'tData01 tt' })
        
                    # 크롤링
        
                    table1 = parser_functions.make2d(data)

                    df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
                    if df1.empty:
                        pass
                    else:
                        # print(df1)
                        df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team_2[T]) +'_'+ '월별' +'_'+ '{}'.format(position[P]) +'_' + '{}'.format(detail[D]) + '선수기록.csv', encoding = 'utf-8')
    elif year[Y] in ["2021", "2022", "2023"]:
        for T in team_3: 
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
            time.sleep(1.3)
            for P in position:
                driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlPos_ddlPos"]/option[{}]'.format(P)).click() # 포지션별
                time.sleep(1.5)
                # 월별
                driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituation_ddlSituation"]/option[2]').click() # 상황별 1
                time.sleep(1.5)
                for D in detail:
                    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail"]/option[{}]'.format(D)).click()
                    time.sleep(1.5)

                    html = driver.page_source
                    soup = BeautifulSoup(html, 'html.parser')
                    data = soup.find('table', { 'class': 'tData01 tt' })
        
                    # 크롤링
        
                    table1 = parser_functions.make2d(data)

                    df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
                    if df1.empty:
                        pass
                    else:
                        # print(df1)
                        df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team_3[T]) +'_'+ '월별' +'_'+ '{}'.format(position[P]) +'_' +'{}'.format(detail[D]) + '선수기록.csv', encoding = 'utf-8')
# Out:
# C:\Users\nhw85\AppData\Local\Temp\ipykernel_62572\1740625925.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %% [markdown]
# #### KBO 연간_정규시즌_팀별_포지션별_월별(투수)

# %%
path = "C://Users//nhw85//Downloads//chromedriver_win32//chromedriver.exe"

driver = webdriver.Chrome(path)

year = {36 : "2017", 37 : "2018", 38 : "2019", 39 : "2020", 40 : "2021", 41 : "2022", 42 : "2023"}
team_1 = {2:"넥센", 3:"두산", 4: "롯데", 5: "삼성", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
team_2 = {2:"두산", 3:"롯데", 4: "삼성", 5: "키움", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
team_3 = {2:"두산", 3:"롯데", 4: "삼성", 5: "키움", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SSG" }
season = {1: "정규시즌", 2: "시범경기", 3: "와일드카드", 4: "준플레이오프", 5: "플레이오프", 6: "한국시리즈"}
position = {2: "포수", 3: "내야수", 4: "외야수"}
situation = 2 # 월별
detail = {2: "3~4월", 3: "5월", 4: "6월", 5: "7월", 6: "8월", 7: "9월이상" }



category_list = ['HitterBasic/Basic1.aspx', 'PitcherBasic/Basic1.aspx', 
                'Defense/Basic.aspx', 'Runner/Basic.aspx']

driver.get('https://www.koreabaseball.com/Record/Player/PitcherBasic/Basic1.aspx')

for Y in year:
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeason_ddlSeason"]/option[{}]'.format(Y)).click() # 연도
    time.sleep(1)
    # season
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeries_ddlSeries"]/option[1]').click() # Season
    time.sleep(1)
    if year[Y] in ["2017", "2018"]:
        for T in team_1: 
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
            time.sleep(1.3)

            # 월별
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituation_ddlSituation"]/option[2]').click() # 상황별 1
            time.sleep(1.5)
            for D in detail:
                driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail"]/option[{}]'.format(D)).click()
                time.sleep(1.5)

                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                data = soup.find('table', { 'class': 'tData01 tt' })
    
                # 크롤링
    
                table1 = parser_functions.make2d(data)

                df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
                if df1.empty:
                    pass
                else:
                    # print(df1)
                    df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team_1[T]) +'_'+ '월별' +'_'+'{}'.format(detail[D]) + '선수기록(투수).csv', encoding = 'utf-8')
    elif year[Y] in ["2019", "2020"]:
        for T in team_2: 
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
            time.sleep(1.3)

            # 월별
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituation_ddlSituation"]/option[2]').click() # 상황별 1
            time.sleep(1.5)
            for D in detail:
                driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail"]/option[{}]'.format(D)).click()
                time.sleep(1.5)

                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                data = soup.find('table', { 'class': 'tData01 tt' })
    
                # 크롤링
    
                table1 = parser_functions.make2d(data)

                df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
                if df1.empty:
                    pass
                else:
                    # print(df1)
                    df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team_2[T]) +'_'+ '월별' +'_'+'{}'.format(detail[D]) + '선수기록(투수).csv', encoding = 'utf-8')
    elif year[Y] in ["2021", "2022", "2023"]:
        for T in team_3: 
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
            time.sleep(1.3)

            # 월별
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituation_ddlSituation"]/option[2]').click() # 상황별 1
            time.sleep(1.5)
            for D in detail:
                driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail"]/option[{}]'.format(D)).click()
                time.sleep(1.5)

                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                data = soup.find('table', { 'class': 'tData01 tt' })
    
                # 크롤링
    
                table1 = parser_functions.make2d(data)

                df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
                if df1.empty:
                    pass
                else:
                    # print(df1)
                    df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team_3[T]) +'_'+ '월별' +'_'+'{}'.format(detail[D]) + '선수기록(투수).csv', encoding = 'utf-8')
# Out:
# C:\Users\nhw85\AppData\Local\Temp\ipykernel_69772\1488571617.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %%
path = "C://Users//nhw85//Downloads//chromedriver_win32//chromedriver.exe"

driver = webdriver.Chrome(path)

year = {36 : "2017", 37 : "2018", 38 : "2019", 39 : "2020", 40 : "2021", 41 : "2022", 42 : "2023"}
team = {2: "넥센", 3:"두산", 4: "롯데", 5: "삼성", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
position = {2: "포수", 3: "내야수", 4: "외야수"}
situation = 5 # 홈/방문
detail = {2: "홈", 3: "방문"}
target = {1: "타자", 2: "투수"}

category_list = ['HitterBasic/Basic1.aspx', 'PitcherBasic/Basic1.aspx', 
                'Defense/Basic.aspx', 'Runner/Basic.aspx']

driver.get('https://www.koreabaseball.com/Record/Player/HitterBasic/Basic1.aspx')

for Y in year:
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeason_ddlSeason"]/option[{}]'.format(Y)).click() # 연도
    time.sleep(1)
    # season
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeries_ddlSeries"]/option[1]').click() # Season
    time.sleep(1)
    for T in team:
        for W in target:
            filename = save_hir_file("팀별_월별_성적", year[Y], team[T], target[W])
# Out:
# C:\Users\nhw85\AppData\Local\Temp\ipykernel_72304\2547531916.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# ('팀별_월별_성적', '2017', '넥센', '타자')
# ('팀별_월별_성적', '2017', '넥센', '투수')
# ('팀별_월별_성적', '2017', '두산', '타자')
# ('팀별_월별_성적', '2017', '두산', '투수')
# ('팀별_월별_성적', '2017', '롯데', '타자')
# ('팀별_월별_성적', '2017', '롯데', '투수')
# ('팀별_월별_성적', '2017', '삼성', '타자')
# ('팀별_월별_성적', '2017', '삼성', '투수')
# ('팀별_월별_성적', '2017', '한화', '타자')
# ('팀별_월별_성적', '2017', '한화', '투수')
# ('팀별_월별_성적', '2017', 'KIA', '타자')
# ('팀별_월별_성적', '2017', 'KIA', '투수')
# ('팀별_월별_성적', '2017', 'KT', '타자')
# ('팀별_월별_성적', '2017', 'KT', '투수')
# ('팀별_월별_성적', '2017', 'LG', '타자')
# ('팀별_월별_성적', '2017', 'LG', '투수')
# ('팀별_월별_성적', '2017', 'NC', '타자')
# ('팀별_월별_성적', '2017', 'NC', '투수')
# ('팀별_월별_성적', '2017', 'SK', '타자')
# ('팀별_월별_성적', '2017', 'SK', '투수')
# ('팀별_월별_성적', '2018', '넥센', '타자')
# ('팀별_월별_성적', '2018', '넥센', '투수')
# ('팀별_월별_성적', '2018', '두산', '타자')
# ('팀별_월별_성적', '2018', '두산', '투수')
# ('팀별_월별_성적', '2018', '롯데', '타자')
# ('팀별_월별_성적', '2018', '롯데', '투수')
# ('팀별_월별_성적', '2018', '삼성', '타자')
# ('팀별_월별_성적', '2018', '삼성', '투수')
# ('팀별_월별_성적', '2018', '한화', '타자')
# ('팀별_월별_성적', '2018', '한화', '투수')
# ('팀별_월별_성적', '2018', 'KIA', '타자')
# ('팀별_월별_성적', '2018', 'KIA', '투수')
# ('팀별_월별_성적', '2018', 'KT', '타자')
# ('팀별_월별_성적', '2018', 'KT', '투수')
# ('팀별_월별_성적', '2018', 'LG', '타자')
# ('팀별_월별_성적', '2018', 'LG', '투수')
# ('팀별_월별_성적', '2018', 'NC', '타자')
# ('팀별_월별_성적', '2018', 'NC', '투수')
# ('팀별_월별_성적', '2018', 'SK', '타자')
# ('팀별_월별_성적', '2018', 'SK', '투수')
# ('팀별_월별_성적', '2019', '넥센', '타자')
# ('팀별_월별_성적', '2019', '넥센', '투수')
# ('팀별_월별_성적', '2019', '두산', '타자')
# ('팀별_월별_성적', '2019', '두산', '투수')
# ('팀별_월별_성적', '2019', '롯데', '타자')
# ('팀별_월별_성적', '2019', '롯데', '투수')
# ('팀별_월별_성적', '2019', '삼성', '타자')
# ('팀별_월별_성적', '2019', '삼성', '투수')
# ('팀별_월별_성적', '2019', '한화', '타자')
# ('팀별_월별_성적', '2019', '한화', '투수')
# ('팀별_월별_성적', '2019', 'KIA', '타자')
# ('팀별_월별_성적', '2019', 'KIA', '투수')
# ('팀별_월별_성적', '2019', 'KT', '타자')
# ('팀별_월별_성적', '2019', 'KT', '투수')
# ('팀별_월별_성적', '2019', 'LG', '타자')
# ('팀별_월별_성적', '2019', 'LG', '투수')
# ('팀별_월별_성적', '2019', 'NC', '타자')
# ('팀별_월별_성적', '2019', 'NC', '투수')
# ('팀별_월별_성적', '2019', 'SK', '타자')
# ('팀별_월별_성적', '2019', 'SK', '투수')
# ('팀별_월별_성적', '2020', '넥센', '타자')
# ('팀별_월별_성적', '2020', '넥센', '투수')
# ('팀별_월별_성적', '2020', '두산', '타자')
# ('팀별_월별_성적', '2020', '두산', '투수')
# ('팀별_월별_성적', '2020', '롯데', '타자')
# ('팀별_월별_성적', '2020', '롯데', '투수')
# ('팀별_월별_성적', '2020', '삼성', '타자')
# ('팀별_월별_성적', '2020', '삼성', '투수')
# ('팀별_월별_성적', '2020', '한화', '타자')
# ('팀별_월별_성적', '2020', '한화', '투수')
# ('팀별_월별_성적', '2020', 'KIA', '타자')
# ('팀별_월별_성적', '2020', 'KIA', '투수')
# ('팀별_월별_성적', '2020', 'KT', '타자')
# ('팀별_월별_성적', '2020', 'KT', '투수')
# ('팀별_월별_성적', '2020', 'LG', '타자')
# ('팀별_월별_성적', '2020', 'LG', '투수')
# ('팀별_월별_성적', '2020', 'NC', '타자')
# ('팀별_월별_성적', '2020', 'NC', '투수')
# ('팀별_월별_성적', '2020', 'SK', '타자')
# ('팀별_월별_성적', '2020', 'SK', '투수')
# ('팀별_월별_성적', '2021', '넥센', '타자')
# ('팀별_월별_성적', '2021', '넥센', '투수')
# ('팀별_월별_성적', '2021', '두산', '타자')
# ('팀별_월별_성적', '2021', '두산', '투수')
# ('팀별_월별_성적', '2021', '롯데', '타자')
# ('팀별_월별_성적', '2021', '롯데', '투수')
# ('팀별_월별_성적', '2021', '삼성', '타자')
# ('팀별_월별_성적', '2021', '삼성', '투수')
# ('팀별_월별_성적', '2021', '한화', '타자')
# ('팀별_월별_성적', '2021', '한화', '투수')
# ('팀별_월별_성적', '2021', 'KIA', '타자')
# ('팀별_월별_성적', '2021', 'KIA', '투수')
# ('팀별_월별_성적', '2021', 'KT', '타자')
# ('팀별_월별_성적', '2021', 'KT', '투수')
# ('팀별_월별_성적', '2021', 'LG', '타자')
# ('팀별_월별_성적', '2021', 'LG', '투수')
# ('팀별_월별_성적', '2021', 'NC', '타자')
# ('팀별_월별_성적', '2021', 'NC', '투수')
# ('팀별_월별_성적', '2021', 'SK', '타자')
# ('팀별_월별_성적', '2021', 'SK', '투수')
# ('팀별_월별_성적', '2022', '넥센', '타자')
# ('팀별_월별_성적', '2022', '넥센', '투수')
# ('팀별_월별_성적', '2022', '두산', '타자')
# ('팀별_월별_성적', '2022', '두산', '투수')
# ('팀별_월별_성적', '2022', '롯데', '타자')
# ('팀별_월별_성적', '2022', '롯데', '투수')
# ('팀별_월별_성적', '2022', '삼성', '타자')
# ('팀별_월별_성적', '2022', '삼성', '투수')
# ('팀별_월별_성적', '2022', '한화', '타자')
# ('팀별_월별_성적', '2022', '한화', '투수')
# ('팀별_월별_성적', '2022', 'KIA', '타자')
# ('팀별_월별_성적', '2022', 'KIA', '투수')
# ('팀별_월별_성적', '2022', 'KT', '타자')
# ('팀별_월별_성적', '2022', 'KT', '투수')
# ('팀별_월별_성적', '2022', 'LG', '타자')
# ('팀별_월별_성적', '2022', 'LG', '투수')
# ('팀별_월별_성적', '2022', 'NC', '타자')
# ('팀별_월별_성적', '2022', 'NC', '투수')
# ('팀별_월별_성적', '2022', 'SK', '타자')
# ('팀별_월별_성적', '2022', 'SK', '투수')
# ('팀별_월별_성적', '2023', '넥센', '타자')
# ('팀별_월별_성적', '2023', '넥센', '투수')
# ('팀별_월별_성적', '2023', '두산', '타자')
# ('팀별_월별_성적', '2023', '두산', '투수')
# ('팀별_월별_성적', '2023', '롯데', '타자')
# ('팀별_월별_성적', '2023', '롯데', '투수')
# ('팀별_월별_성적', '2023', '삼성', '타자')
# ('팀별_월별_성적', '2023', '삼성', '투수')
# ('팀별_월별_성적', '2023', '한화', '타자')
# ('팀별_월별_성적', '2023', '한화', '투수')
# ('팀별_월별_성적', '2023', 'KIA', '타자')
# ('팀별_월별_성적', '2023', 'KIA', '투수')
# ('팀별_월별_성적', '2023', 'KT', '타자')
# ('팀별_월별_성적', '2023', 'KT', '투수')
# ('팀별_월별_성적', '2023', 'LG', '타자')
# ('팀별_월별_성적', '2023', 'LG', '투수')
# ('팀별_월별_성적', '2023', 'NC', '타자')
# ('팀별_월별_성적', '2023', 'NC', '투수')
# ('팀별_월별_성적', '2023', 'SK', '타자')
# ('팀별_월별_성적', '2023', 'SK', '투수')

# %%
os.chdir("C://Users//nhw85//OneDrive//바탕 화면//새 폴더")
os.getcwd() # "C:\Users\nhw85\Downloads\타자\타자\2023_정규시즌_포수_한화_상대팀별_키움선수기록(타자).csv"
import shutil

file_list = os.listdir()
years = ['2017', '2018', '2019', '2020', '2021', '2022', '2023']
Categorized_team = os.listdir("C://Users//nhw85//OneDrive//바탕 화면//야구 데이터//팀별_상대별_성적//2017")
for y in years:
    for file in file_list: 
        year, title, team, mon, monthdetail = file.split('_') # "C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_월별_내야수_3~4월_선수기록.csv"
        downloaded_file_loc = os.path.abspath(file)
        for t in Categorized_team: 
            if team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_월별_성적//{}//{}//투수".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_월별_성적//{}//{}//투수".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_월별_성적//{}//{}//투수".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_월별_성적//{}//{}//투수".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_월별_성적//{}//{}//투수".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_월별_성적//{}//{}//투수".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_월별_성적//{}//{}//투수".format(y, team))

# %% [markdown]
# #### KBO 연간_정규시즌_팀별_포지션별_요일별(타자)

# %%
path = "C://Users//nhw85//Downloads//chromedriver_win32//chromedriver.exe"

driver = webdriver.Chrome(path)

year = {36 : "2017", 37 : "2018", 38 : "2019", 39 : "2020", 40 : "2021", 41 : "2022", 42 : "2023"}
team_1 = {2:"넥센", 3:"두산", 4: "롯데", 5: "삼성", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
team_2 = {2:"두산", 3:"롯데", 4: "삼성", 5: "키움", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
team_3 = {2:"두산", 3:"롯데", 4: "삼성", 5: "키움", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SSG" }
season = {1: "정규시즌", 2: "시범경기", 3: "와일드카드", 4: "준플레이오프", 5: "플레이오프", 6: "한국시리즈"}
position = {2: "포수", 3: "내야수", 4: "외야수"}
situation = 2 # 월별
detail = {2: "3~4월", 3: "5월", 4: "6월", 5: "7월", 6: "8월", 7: "9월이상" }



category_list = ['HitterBasic/Basic1.aspx', 'PitcherBasic/Basic1.aspx', 
                'Defense/Basic.aspx', 'Runner/Basic.aspx']

driver.get('https://www.koreabaseball.com/Record/Player/HitterBasic/Basic1.aspx')

for Y in year:
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeason_ddlSeason"]/option[{}]'.format(Y)).click() # 연도
    time.sleep(1)
    # season
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeries_ddlSeries"]/option[1]').click() # Season
    time.sleep(1)
    if year[Y] in ["2017", "2018"]:
        for T in team_1: 
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
            time.sleep(1.3)
            for P in position:
                driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlPos_ddlPos"]/option[{}]'.format(P)).click() # 포지션별
                time.sleep(1.5)
                # 월별
                driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituation_ddlSituation"]/option[3]').click() # 상황별 1/ 요일별
                time.sleep(1.5)
                for D in detail:
                    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail"]/option[{}]'.format(D)).click()
                    time.sleep(1.5)

                    html = driver.page_source
                    soup = BeautifulSoup(html, 'html.parser')
                    data = soup.find('table', { 'class': 'tData01 tt' })
        
                    # 크롤링
        
                    table1 = parser_functions.make2d(data)

                    df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
                    if df1.empty:
                        pass
                    else:
                        # print(df1)
                        df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team_1[T]) +'_'+ '월별' +'_'+ '{}'.format(position[P]) +'_'+'{}'.format(detail[D]) + '선수기록.csv', encoding = 'utf-8')
    elif year[Y] in ["2019", "2020"]:
        for T in team_1: 
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
            time.sleep(1.3)
            for P in position:
                driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlPos_ddlPos"]/option[{}]'.format(P)).click() # 포지션별
                time.sleep(1.5)
                # 월별
                driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituation_ddlSituation"]/option[2]').click() # 상황별 1
                time.sleep(1.5)
                for D in detail:
                    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail"]/option[{}]'.format(D)).click()
                    time.sleep(1.5)

                    html = driver.page_source
                    soup = BeautifulSoup(html, 'html.parser')
                    data = soup.find('table', { 'class': 'tData01 tt' })
        
                    # 크롤링
        
                    table1 = parser_functions.make2d(data)

                    df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
                    if df1.empty:
                        pass
                    else:
                        # print(df1)
                        df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team_2[T]) +'_'+ '월별' +'_'+ '{}'.format(position[P]) +'_' + '{}'.format(detail[D]) + '선수기록.csv', encoding = 'utf-8')
    elif year[Y] in ["2021", "2022", "2023"]:
        for T in team_1: 
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
            time.sleep(1.3)
            for P in position:
                driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlPos_ddlPos"]/option[{}]'.format(P)).click() # 포지션별
                time.sleep(1.5)
                # 월별
                driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituation_ddlSituation"]/option[2]').click() # 상황별 1
                time.sleep(1.5)
                for D in detail:
                    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail"]/option[{}]'.format(D)).click()
                    time.sleep(1.5)

                    html = driver.page_source
                    soup = BeautifulSoup(html, 'html.parser')
                    data = soup.find('table', { 'class': 'tData01 tt' })
        
                    # 크롤링
        
                    table1 = parser_functions.make2d(data)

                    df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
                    if df1.empty:
                        pass
                    else:
                        # print(df1)
                        df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team_3[T]) +'_'+ '월별' +'_'+ '{}'.format(position[P]) +'_' +'{}'.format(detail[D]) + '선수기록.csv', encoding = 'utf-8')
# Out:
# C:\Users\nhw85\AppData\Local\Temp\ipykernel_66088\2993873404.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %%
path = "C://Users//nhw85//Downloads//chromedriver_win32//chromedriver.exe"

driver = webdriver.Chrome(path)

year = {36 : "2017", 37 : "2018", 38 : "2019", 39 : "2020", 40 : "2021", 41 : "2022", 42 : "2023"}
team = {2: "넥센", 3:"두산", 4: "롯데", 5: "삼성", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
position = {2: "포수", 3: "내야수", 4: "외야수"}
situation = 5 # 홈/방문
detail = {2: "홈", 3: "방문"}
target = {1: "타자", 2: "투수"}


category_list = ['HitterBasic/Basic1.aspx', 'PitcherBasic/Basic1.aspx', 
                'Defense/Basic.aspx', 'Runner/Basic.aspx']

driver.get('https://www.koreabaseball.com/Record/Player/HitterBasic/Basic1.aspx')

for Y in year:
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeason_ddlSeason"]/option[{}]'.format(Y)).click() # 연도
    time.sleep(1)
    # season
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeries_ddlSeries"]/option[1]').click() # Season
    time.sleep(1)
    for T in team:
        for W in target:
            filename = save_hir_file("팀별_요일별_성적", year[Y], team[T], target[W])

# %% [markdown]
# 자동 저장 code

# %%
os.chdir("C://Users//nhw85//OneDrive//바탕 화면//새 폴더")
os.getcwd()

file_list = os.listdir()
file_list

# %%
os.chdir("C://Users//nhw85//OneDrive//바탕 화면//새 폴더")
os.getcwd() # "C:\Users\nhw85\Downloads\타자\타자\2023_정규시즌_포수_한화_상대팀별_키움선수기록(타자).csv"
import shutil

file_list = os.listdir()
years = ['2017', '2018', '2019', '2020', '2021', '2022', '2023']
Categorized_team = os.listdir("C://Users//nhw85//OneDrive//바탕 화면//야구 데이터//팀별_상대별_성적//2017")
for y in years:
    for file in file_list: 
        year, title, team, sub_title, day, detail = file.split('_') 
        downloaded_file_loc = os.path.abspath(file)
        for t in Categorized_team: # C:\Users\nhw85\OneDrive\바탕 화면\팀별_요일별_성적\2017\KIA\타자
            if team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_요일별_성적//{}//{}//타자".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_요일별_성적//{}//{}//타자".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_요일별_성적//{}//{}//타자".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_요일별_성적//{}//{}//타자".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_요일별_성적//{}//{}//타자".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_요일별_성적//{}//{}//타자".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_요일별_성적//{}//{}//타자".format(y, team))

# %% [markdown]
# #### KBO 연간_정규시즌_팀별_포지션별_홈/방문별_홈/방문(타자)

# %%
path = "C://Users//nhw85//Downloads//chromedriver_win32 (1)//chromedriver.exe"

driver = webdriver.Chrome(path)


year = {36 : "2017", 37 : "2018", 38 : "2019", 39 : "2020", 40 : "2021", 41 : "2022", 42 : "2023"}
Defense_year = [17, 18, 19, 20, 21, 22, 23]
Runner_year = [17, 18, 19, 20, 21, 22, 23]
team = {2:"두산", 3:"롯데", 4: "삼성", 5: "키움", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
season = {1: "정규시즌", 2: "시범경기", 3: "와일드카드", 4: "준플레이오프", 5: "플레이오프", 6: "한국시리즈"}
position = {2: "포수", 3: "내야수", 4: "외야수"}
situation = 5 # 홈/방문
detail = {2: "홈", 3: "어웨이"}



category_list = ['HitterBasic/Basic1.aspx', 'PitcherBasic/Basic1.aspx', 
                'Defense/Basic.aspx', 'Runner/Basic.aspx']

driver.get('https://www.koreabaseball.com/Record/Player/HitterBasic/Basic1.aspx')

for Y in year:
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeason_ddlSeason"]/option[{}]'.format(Y)).click() # 연도
    time.sleep(1)
    # season
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeries_ddlSeries"]/option[1]').click() # Season
    time.sleep(1)
    for T in team: 
        driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
        time.sleep(1.3)
        for P in position:
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlPos_ddlPos"]/option[{}]'.format(P)).click() # 포지션별
            time.sleep(1.5)
            # 홈/방문
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituation_ddlSituation"]/option[5]').click() # 상황별 1
            time.sleep(1.5)
            for D in detail:
                driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail"]/option[{}]'.format(D)).click() # 상황별 2
                time.sleep(1.5)

                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                data = soup.find('table', { 'class': 'tData01 tt' })
    
                # 크롤링
    
                table1 = parser_functions.make2d(data)

                df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
                if df1.empty:
                    pass
                else:
                    # print(df1)
                    df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team[T]) +'_'+'{}'.format(position[P])+ '홈_어웨이별' +'_'+ '{}'.format(detail[D])+ '_' + '선수기록(타자).csv', encoding = 'utf-8')
# Out:
# C:\Users\nhw85\AppData\Local\Temp\ipykernel_32384\1402238059.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %% [markdown]
# 파일 자동 저장 Code

# %%
os.chdir("C://Users//nhw85//OneDrive//바탕 화면//새 폴더")
os.getcwd() # "C:\Users\nhw85\Downloads\타자\타자\2023_정규시즌_포수_한화_상대팀별_키움선수기록(타자).csv"
import shutil

file_list = os.listdir()
years = ['2017', '2018', '2019', '2020', '2021', '2022', '2023']
Categorized_team = os.listdir("C://Users//nhw85//OneDrive//바탕 화면//야구 데이터//팀별_상대별_성적//2017")
for y in years:
    for file in file_list: # "C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_내야수홈_어웨이별_어웨이_선수기록(타자).csv"
        year, title, team, sub_title, type, type2, detail = file.split('_')
        # print(year, title, team, sub_title, _, detail)
        downloaded_file_loc = os.path.abspath(file)
        print(downloaded_file_loc)
        for t in Categorized_team: # C:\Users\nhw85\OneDrive\바탕 화면\팀별_홈_방문별_성적\2017\KIA\타자
            if team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_홈_방문별_성적//{}//{}//타자".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_홈_방문별_성적//{}//{}//타자".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_홈_방문별_성적//{}//{}//타자".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_홈_방문별_성적//{}//{}//타자".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_홈_방문별_성적//{}//{}//타자".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_홈_방문별_성적//{}//{}//타자".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_홈_방문별_성적//{}//{}//타자".format(y, team))

# %% [markdown]
# #### KBO 연간_정규시즌_팀별_포지션별_홈/방문별_홈/방문(투수)

# %%
path = "C://Users//nhw85//Downloads//chromedriver_win32 (1)//chromedriver.exe"

driver = webdriver.Chrome(path)


year = {36 : "2017", 37 : "2018", 38 : "2019", 39 : "2020", 40 : "2021", 41 : "2022", 42 : "2023"}
Defense_year = [17, 18, 19, 20, 21, 22, 23]
Runner_year = [17, 18, 19, 20, 21, 22, 23]
team = {2:"두산", 3:"롯데", 4: "삼성", 5: "키움", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
season = {1: "정규시즌", 2: "시범경기", 3: "와일드카드", 4: "준플레이오프", 5: "플레이오프", 6: "한국시리즈"}
situation = 5 # 홈/방문
detail = {2: "홈", 3: "어웨이"}



category_list = ['HitterBasic/Basic1.aspx', 'PitcherBasic/Basic1.aspx', 
                'Defense/Basic.aspx', 'Runner/Basic.aspx']

driver.get('https://www.koreabaseball.com/Record/Player/PitcherBasic/Basic1.aspx')

for Y in year:
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeason_ddlSeason"]/option[{}]'.format(Y)).click() # 연도
    time.sleep(1)
    # season
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeries_ddlSeries"]/option[1]').click() # Season
    time.sleep(1)
    for T in team: 
        driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
        time.sleep(1.3)
        # 홈/방문
        driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituation_ddlSituation"]/option[5]').click() # 상황별 1
        time.sleep(1.5)
        for D in detail:
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail"]/option[{}]'.format(D)).click() # 상황별 2
            time.sleep(1.5)

            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            data = soup.find('table', { 'class': 'tData01 tt' })

            # 크롤링

            table1 = parser_functions.make2d(data)

            df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
            if df1.empty:
                pass
            else:
                # print(df1)
                df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team[T]) +'_' + '홈어웨이별' +'_'+ '{}'.format(detail[D])+ '_' + '선수기록(투수).csv', encoding = 'utf-8')
# Out:
# C:\Users\nhw85\AppData\Local\Temp\ipykernel_30080\3015673027.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %% [markdown]
# 파일 자동 저장code

# %%
os.chdir("C://Users//nhw85//OneDrive//바탕 화면//새 폴더")
os.getcwd() # "C:\Users\nhw85\Downloads\타자\타자\2023_정규시즌_포수_한화_상대팀별_키움선수기록(타자).csv"
import shutil

file_list = os.listdir()
years = ['2017', '2018', '2019', '2020', '2021', '2022', '2023']
Categorized_team = os.listdir("C://Users//nhw85//OneDrive//바탕 화면//야구 데이터//팀별_상대별_성적//2017")
for y in years:
    for file in file_list: # "C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_홈어웨이별_어웨이_선수기록(투수).csv"
        year, title, team, sub_title, type, detail = file.split('_')
        # print(year, title, team, sub_title, _, detail)
        downloaded_file_loc = os.path.abspath(file)
        print(downloaded_file_loc)
        for t in Categorized_team: # C:\Users\nhw85\OneDrive\바탕 화면\팀별_홈_방문별_성적\2017\KIA\타자
            if team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_홈_방문별_성적//{}//{}//투수".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_홈_방문별_성적//{}//{}//투수".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_홈_방문별_성적//{}//{}//투수".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_홈_방문별_성적//{}//{}//투수".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_홈_방문별_성적//{}//{}//투수".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_홈_방문별_성적//{}//{}//투수".format(y, team))
            elif team == t and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_홈_방문별_성적//{}//{}//투수".format(y, team))

# %% [markdown]
# #### 파일 만드는 함수

# %%
import os

def save_hir_file(*args, ):
    print(args[:])
    if len(args) == 1:
        return args[0]
    dirname = "/".join(args[:])
    os.makedirs(dirname, exist_ok = False)
    return "/".join(args)

# %% [markdown]
# #### 파일 자동 생성 코드

# %%
path = "C://Users//nhw85//Downloads//chromedriver_win32//chromedriver.exe"

driver = webdriver.Chrome(path)

year = {36 : "2017", 37 : "2018", 38 : "2019", 39 : "2020", 40 : "2021", 41 : "2022", 42 : "2023"}
team = {2:"두산", 3:"롯데", 4: "삼성", 5: "키움", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
position = {2: "포수", 3: "내야수", 4: "외야수"}
situation = 5 # 홈/방문
detail = {2: "홈", 3: "방문"}
target = {1: "타자", 2: "투수"}


category_list = ['HitterBasic/Basic1.aspx', 'PitcherBasic/Basic1.aspx', 
                'Defense/Basic.aspx', 'Runner/Basic.aspx']

driver.get('https://www.koreabaseball.com/Record/Player/HitterBasic/Basic1.aspx')

for Y in year:
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeason_ddlSeason"]/option[{}]'.format(Y)).click() # 연도
    time.sleep(1)
    # season
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeries_ddlSeries"]/option[1]').click() # Season
    time.sleep(1)
    for T in team:
        for W in target:
            filename = save_hir_file("팀별_주간야간별_성적", year[Y], team[T], target[W])
# Out:
# C:\Users\nhw85\AppData\Local\Temp\ipykernel_35020\4106175978.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
# ('팀별_주간야간별_성적', '2017', '두산', '타자')
# ('팀별_주간야간별_성적', '2017', '두산', '투수')
# ('팀별_주간야간별_성적', '2017', '롯데', '타자')
# ('팀별_주간야간별_성적', '2017', '롯데', '투수')
# ('팀별_주간야간별_성적', '2017', '삼성', '타자')
# ('팀별_주간야간별_성적', '2017', '삼성', '투수')
# ('팀별_주간야간별_성적', '2017', '키움', '타자')
# ('팀별_주간야간별_성적', '2017', '키움', '투수')
# ('팀별_주간야간별_성적', '2017', '한화', '타자')
# ('팀별_주간야간별_성적', '2017', '한화', '투수')
# ('팀별_주간야간별_성적', '2017', 'KIA', '타자')
# ('팀별_주간야간별_성적', '2017', 'KIA', '투수')
# ('팀별_주간야간별_성적', '2017', 'KT', '타자')
# ('팀별_주간야간별_성적', '2017', 'KT', '투수')
# ('팀별_주간야간별_성적', '2017', 'LG', '타자')
# ('팀별_주간야간별_성적', '2017', 'LG', '투수')
# ('팀별_주간야간별_성적', '2017', 'NC', '타자')
# ('팀별_주간야간별_성적', '2017', 'NC', '투수')
# ('팀별_주간야간별_성적', '2017', 'SK', '타자')
# ('팀별_주간야간별_성적', '2017', 'SK', '투수')
# ('팀별_주간야간별_성적', '2018', '두산', '타자')
# ('팀별_주간야간별_성적', '2018', '두산', '투수')
# ('팀별_주간야간별_성적', '2018', '롯데', '타자')
# ('팀별_주간야간별_성적', '2018', '롯데', '투수')
# ('팀별_주간야간별_성적', '2018', '삼성', '타자')
# ('팀별_주간야간별_성적', '2018', '삼성', '투수')
# ('팀별_주간야간별_성적', '2018', '키움', '타자')
# ('팀별_주간야간별_성적', '2018', '키움', '투수')
# ('팀별_주간야간별_성적', '2018', '한화', '타자')
# ('팀별_주간야간별_성적', '2018', '한화', '투수')
# ('팀별_주간야간별_성적', '2018', 'KIA', '타자')
# ('팀별_주간야간별_성적', '2018', 'KIA', '투수')
# ('팀별_주간야간별_성적', '2018', 'KT', '타자')
# ('팀별_주간야간별_성적', '2018', 'KT', '투수')
# ('팀별_주간야간별_성적', '2018', 'LG', '타자')
# ('팀별_주간야간별_성적', '2018', 'LG', '투수')
# ('팀별_주간야간별_성적', '2018', 'NC', '타자')
# ('팀별_주간야간별_성적', '2018', 'NC', '투수')
# ('팀별_주간야간별_성적', '2018', 'SK', '타자')
# ('팀별_주간야간별_성적', '2018', 'SK', '투수')
# ('팀별_주간야간별_성적', '2019', '두산', '타자')
# ('팀별_주간야간별_성적', '2019', '두산', '투수')
# ('팀별_주간야간별_성적', '2019', '롯데', '타자')
# ('팀별_주간야간별_성적', '2019', '롯데', '투수')
# ('팀별_주간야간별_성적', '2019', '삼성', '타자')
# ('팀별_주간야간별_성적', '2019', '삼성', '투수')
# ('팀별_주간야간별_성적', '2019', '키움', '타자')
# ('팀별_주간야간별_성적', '2019', '키움', '투수')
# ('팀별_주간야간별_성적', '2019', '한화', '타자')
# ('팀별_주간야간별_성적', '2019', '한화', '투수')
# ('팀별_주간야간별_성적', '2019', 'KIA', '타자')
# ('팀별_주간야간별_성적', '2019', 'KIA', '투수')
# ('팀별_주간야간별_성적', '2019', 'KT', '타자')
# ('팀별_주간야간별_성적', '2019', 'KT', '투수')
# ('팀별_주간야간별_성적', '2019', 'LG', '타자')
# ('팀별_주간야간별_성적', '2019', 'LG', '투수')
# ('팀별_주간야간별_성적', '2019', 'NC', '타자')
# ('팀별_주간야간별_성적', '2019', 'NC', '투수')
# ('팀별_주간야간별_성적', '2019', 'SK', '타자')
# ('팀별_주간야간별_성적', '2019', 'SK', '투수')
# ('팀별_주간야간별_성적', '2020', '두산', '타자')
# ('팀별_주간야간별_성적', '2020', '두산', '투수')
# ('팀별_주간야간별_성적', '2020', '롯데', '타자')
# ('팀별_주간야간별_성적', '2020', '롯데', '투수')
# ('팀별_주간야간별_성적', '2020', '삼성', '타자')
# ('팀별_주간야간별_성적', '2020', '삼성', '투수')
# ('팀별_주간야간별_성적', '2020', '키움', '타자')
# ('팀별_주간야간별_성적', '2020', '키움', '투수')
# ('팀별_주간야간별_성적', '2020', '한화', '타자')
# ('팀별_주간야간별_성적', '2020', '한화', '투수')
# ('팀별_주간야간별_성적', '2020', 'KIA', '타자')
# ('팀별_주간야간별_성적', '2020', 'KIA', '투수')
# ('팀별_주간야간별_성적', '2020', 'KT', '타자')
# ('팀별_주간야간별_성적', '2020', 'KT', '투수')
# ('팀별_주간야간별_성적', '2020', 'LG', '타자')
# ('팀별_주간야간별_성적', '2020', 'LG', '투수')
# ('팀별_주간야간별_성적', '2020', 'NC', '타자')
# ('팀별_주간야간별_성적', '2020', 'NC', '투수')
# ('팀별_주간야간별_성적', '2020', 'SK', '타자')
# ('팀별_주간야간별_성적', '2020', 'SK', '투수')
# ('팀별_주간야간별_성적', '2021', '두산', '타자')
# ('팀별_주간야간별_성적', '2021', '두산', '투수')
# ('팀별_주간야간별_성적', '2021', '롯데', '타자')
# ('팀별_주간야간별_성적', '2021', '롯데', '투수')
# ('팀별_주간야간별_성적', '2021', '삼성', '타자')
# ('팀별_주간야간별_성적', '2021', '삼성', '투수')
# ('팀별_주간야간별_성적', '2021', '키움', '타자')
# ('팀별_주간야간별_성적', '2021', '키움', '투수')
# ('팀별_주간야간별_성적', '2021', '한화', '타자')
# ('팀별_주간야간별_성적', '2021', '한화', '투수')
# ('팀별_주간야간별_성적', '2021', 'KIA', '타자')
# ('팀별_주간야간별_성적', '2021', 'KIA', '투수')
# ('팀별_주간야간별_성적', '2021', 'KT', '타자')
# ('팀별_주간야간별_성적', '2021', 'KT', '투수')
# ('팀별_주간야간별_성적', '2021', 'LG', '타자')
# ('팀별_주간야간별_성적', '2021', 'LG', '투수')
# ('팀별_주간야간별_성적', '2021', 'NC', '타자')
# ('팀별_주간야간별_성적', '2021', 'NC', '투수')
# ('팀별_주간야간별_성적', '2021', 'SK', '타자')
# ('팀별_주간야간별_성적', '2021', 'SK', '투수')
# ('팀별_주간야간별_성적', '2022', '두산', '타자')
# ('팀별_주간야간별_성적', '2022', '두산', '투수')
# ('팀별_주간야간별_성적', '2022', '롯데', '타자')
# ('팀별_주간야간별_성적', '2022', '롯데', '투수')
# ('팀별_주간야간별_성적', '2022', '삼성', '타자')
# ('팀별_주간야간별_성적', '2022', '삼성', '투수')
# ('팀별_주간야간별_성적', '2022', '키움', '타자')
# ('팀별_주간야간별_성적', '2022', '키움', '투수')
# ('팀별_주간야간별_성적', '2022', '한화', '타자')
# ('팀별_주간야간별_성적', '2022', '한화', '투수')
# ('팀별_주간야간별_성적', '2022', 'KIA', '타자')
# ('팀별_주간야간별_성적', '2022', 'KIA', '투수')
# ('팀별_주간야간별_성적', '2022', 'KT', '타자')
# ('팀별_주간야간별_성적', '2022', 'KT', '투수')
# ('팀별_주간야간별_성적', '2022', 'LG', '타자')
# ('팀별_주간야간별_성적', '2022', 'LG', '투수')
# ('팀별_주간야간별_성적', '2022', 'NC', '타자')
# ('팀별_주간야간별_성적', '2022', 'NC', '투수')
# ('팀별_주간야간별_성적', '2022', 'SK', '타자')
# ('팀별_주간야간별_성적', '2022', 'SK', '투수')
# ('팀별_주간야간별_성적', '2023', '두산', '타자')
# ('팀별_주간야간별_성적', '2023', '두산', '투수')
# ('팀별_주간야간별_성적', '2023', '롯데', '타자')
# ('팀별_주간야간별_성적', '2023', '롯데', '투수')
# ('팀별_주간야간별_성적', '2023', '삼성', '타자')
# ('팀별_주간야간별_성적', '2023', '삼성', '투수')
# ('팀별_주간야간별_성적', '2023', '키움', '타자')
# ('팀별_주간야간별_성적', '2023', '키움', '투수')
# ('팀별_주간야간별_성적', '2023', '한화', '타자')
# ('팀별_주간야간별_성적', '2023', '한화', '투수')
# ('팀별_주간야간별_성적', '2023', 'KIA', '타자')
# ('팀별_주간야간별_성적', '2023', 'KIA', '투수')
# ('팀별_주간야간별_성적', '2023', 'KT', '타자')
# ('팀별_주간야간별_성적', '2023', 'KT', '투수')
# ('팀별_주간야간별_성적', '2023', 'LG', '타자')
# ('팀별_주간야간별_성적', '2023', 'LG', '투수')
# ('팀별_주간야간별_성적', '2023', 'NC', '타자')
# ('팀별_주간야간별_성적', '2023', 'NC', '투수')
# ('팀별_주간야간별_성적', '2023', 'SK', '타자')
# ('팀별_주간야간별_성적', '2023', 'SK', '투수')

# %% [markdown]
# ####  KBO 연간_정규시즌_팀별_포지션별_투수유형별_(좌투수, 우투수, 언더(타자))

# %%
path = "C://Users//nhw85//Downloads//chromedriver_win32 (1)//chromedriver.exe"

driver = webdriver.Chrome(path)


year = {36 : "2017", 37 : "2018", 38 : "2019", 39 : "2020", 40 : "2021", 41 : "2022", 42 : "2023"}
Defense_year = [17, 18, 19, 20, 21, 22, 23]
Runner_year = [17, 18, 19, 20, 21, 22, 23]
team = {2:"두산", 3:"롯데", 4: "삼성", 5: "키움", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
season = {1: "정규시즌", 2: "시범경기", 3: "와일드카드", 4: "준플레이오프", 5: "플레이오프", 6: "한국시리즈"}
position = {2: "포수", 3: "내야수", 4: "외야수"}
situation = 9 # 투수유형별
detail = {2: "좌투수", 3: "우투수", 4: "언더"}



category_list = ['HitterBasic/Basic1.aspx', 'PitcherBasic/Basic1.aspx', 
                'Defense/Basic.aspx', 'Runner/Basic.aspx']

driver.get('https://www.koreabaseball.com/Record/Player/HitterBasic/Basic1.aspx')

for Y in year:
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeason_ddlSeason"]/option[{}]'.format(Y)).click() # 연도
    time.sleep(1)
    # season
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeries_ddlSeries"]/option[1]').click() # Season
    time.sleep(1)
    for T in team: 
        driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
        time.sleep(1.3)
        for P in position:
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlPos_ddlPos"]/option[{}]'.format(P)).click() # 포지션별
            time.sleep(1.5)
            # 홈/방문
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituation_ddlSituation"]/option[9]').click() # 상황별 1
            time.sleep(1.5)
            for D in detail:
                driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail"]/option[{}]'.format(D)).click() # 상황별 2
                time.sleep(1.5)

                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                data = soup.find('table', { 'class': 'tData01 tt' })
    
                # 크롤링
    
                table1 = parser_functions.make2d(data)

                df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
                if df1.empty:
                    pass
                else:
                    # print(df1)
                    df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team[T])+'_'+'{}'.format(position[P]) +'_'+ '투수유형별' +'_'+ '{}'.format(detail[D]) + '선수기록(타자).csv', encoding = 'utf-8')
# Out:
# C:\Users\nhw85\AppData\Local\Temp\ipykernel_27744\2922176970.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %% [markdown]
# #### 파일 자동 저장 code

# %%
os.chdir("C://Users//nhw85//OneDrive//바탕 화면//새 폴더")
os.getcwd() # "C:\Users\nhw85\Downloads\타자\타자\2023_정규시즌_포수_한화_상대팀별_키움선수기록(타자).csv"
import shutil


file_list = os.listdir()
years = ['2017', '2018', '2019', '2020', '2021', '2022', '2023']
Categorized_team = os.listdir("C://Users//nhw85//OneDrive//바탕 화면//야구 데이터//팀별_상대별_성적//2017")
for y in years:
    for file in file_list:
        year, title, team, pos, sub_title, detail = file.split('_')
        # print(year, title, team, sub_title, detail)
        downloaded_file_loc = os.path.abspath(file)
        print(downloaded_file_loc)
        for T in Categorized_team: #C:\Users\nhw85\OneDrive\바탕 화면\팀별_상대별_성적(타자)\2017\KIA\타자
            if team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_상대별_성적(타자)//{}//{}//타자".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_상대별_성적(타자)//{}//{}//타자".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_상대별_성적(타자)//{}//{}//타자".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_상대별_성적(타자)//{}//{}//타자".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_상대별_성적(타자)//{}//{}//타자".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_상대별_성적(타자)//{}//{}//타자".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_상대별_성적(타자)//{}//{}//타자".format(y, team))
# Out:
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_외야수_투수유형별_우투수선수기록(타자).csv
# ...
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_포수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_내야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_내야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_내야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_외야수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_외야수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_외야수_투수유형별_좌투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_포수_투수유형별_언더선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_포수_투수유형별_우투수선수기록(타자).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_포수_투수유형별_좌투수선수기록(타자).csv

# %% [markdown]
# ####  KBO 연간_정규시즌_팀별_타자유형별_(우타자, 좌타자)

# %%
path = "C://Users//nhw85//Downloads//chromedriver_win32 (1)//chromedriver.exe"

driver = webdriver.Chrome(path)


year = {36 : "2017", 37 : "2018", 38 : "2019", 39 : "2020", 40 : "2021", 41 : "2022", 42 : "2023"}
Defense_year = [17, 18, 19, 20, 21, 22, 23]
Runner_year = [17, 18, 19, 20, 21, 22, 23]
team = {2:"두산", 3:"롯데", 4: "삼성", 5: "키움", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
season = {1: "정규시즌", 2: "시범경기", 3: "와일드카드", 4: "준플레이오프", 5: "플레이오프", 6: "한국시리즈"}
position = {2: "포수", 3: "내야수", 4: "외야수"}
situation = 9 # 투수유형별
detail = {2: "우타자", 3:"좌타자"}



category_list = ['HitterBasic/Basic1.aspx', 'PitcherBasic/Basic1.aspx', 
                'Defense/Basic.aspx', 'Runner/Basic.aspx']

driver.get('https://www.koreabaseball.com/Record/Player/PitcherBasic/Basic1.aspx')

for Y in year:
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeason_ddlSeason"]/option[{}]'.format(Y)).click() # 연도
    time.sleep(1)
    # season
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeries_ddlSeries"]/option[1]').click() # Season
    time.sleep(1)
    for T in team: 
        driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
        time.sleep(1.3)
        
        driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituation_ddlSituation"]/option[9]').click() # 상황별 1/ 타자유형별
        time.sleep(1.5)
        
        for D in detail:
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail"]/option[{}]'.format(D)).click() # 상황별 2/좌타자, 우타자
            time.sleep(1.5)

            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            data = soup.find('table', { 'class': 'tData01 tt' })

            # 크롤링

            table1 = parser_functions.make2d(data)

            df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
            if df1.empty:
                pass
            else:
                # print(df1)
                df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team[T]) +'_'+ '타자유형별' +'_'+ '{}'.format(detail[D]) + '_' + '선수기록(투수).csv', encoding = 'utf-8')
# Out:
# C:\Users\nhw85\AppData\Local\Temp\ipykernel_21500\2152957526.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %% [markdown]
# #### 파일 자동 저장

# %%
os.chdir("C://Users//nhw85//OneDrive//바탕 화면//새 폴더")
os.getcwd() # "C:\Users\nhw85\Downloads\타자\타자\2023_정규시즌_포수_한화_상대팀별_키움선수기록(타자).csv"
import shutil

file_list = os.listdir()
years = ['2017', '2018', '2019', '2020', '2021', '2022', '2023']
Categorized_team = os.listdir("C://Users//nhw85//OneDrive//바탕 화면//야구 데이터//팀별_상대별_성적//2017")
for y in years:
    for file in file_list: # 
        year, title, team, sub_title, type, detail = file.split('_')
        # print(year, title, team, sub_title, detail)
        downloaded_file_loc = os.path.abspath(file)
        print(downloaded_file_loc)
        for T in Categorized_team: #C:\Users\nhw85\OneDrive\바탕 화면\팀별_상대별_성적(타자)\2017\KIA\타자
            if team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_투타유형별_성적//{}//{}//타자".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_투타유형별_성적//{}//{}//타자".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_투타유형별_성적//{}//{}//타자".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_투타유형별_성적//{}//{}//타자".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_투타유형별_성적//{}//{}//타자".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_투타유형별_성적//{}//{}//타자".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_투타유형별_성적//{}//{}//타자".format(y, team))
# Out:
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_투수유형별_우투수_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_투수유형별_좌투수_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_투수유형별_우투수_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_투수유형별_좌투수_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_투수유형별_우투수_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_투수유형별_좌투수_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_투수유형별_우투수_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_투수유형별_좌투수_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_투수유형별_우투수_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_투수유형별_좌투수_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# ...
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_투수유형별_우투수_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_투수유형별_좌투수_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_타자유형별_좌타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_타자유형별_우타자_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_타자유형별_좌타자_선수기록(투수).csv

# %% [markdown]
# #### 주간, 야간별(타자)

# %%
path = "C://Users//nhw85//Downloads//chromedriver_win32 (1)//chromedriver.exe"

driver = webdriver.Chrome(path)


year = {36 : "2017", 37 : "2018", 38 : "2019", 39 : "2020", 40 : "2021", 41 : "2022", 42 : "2023"}
team = {2:"두산", 3:"롯데", 4: "삼성", 5: "키움", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
season = {1: "정규시즌", 2: "시범경기", 3: "와일드카드", 4: "준플레이오프", 5: "플레이오프", 6: "한국시리즈"}
position = {2: "포수", 3: "내야수", 4: "외야수"}
situation = 7 # 주간, 야간별
detail = {2: "주간", 3: "야간"}



category_list = ['HitterBasic/Basic1.aspx', 'PitcherBasic/Basic1.aspx', 
                'Defense/Basic.aspx', 'Runner/Basic.aspx']

driver.get('https://www.koreabaseball.com/Record/Player/HitterBasic/Basic1.aspx')

for Y in year:
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeason_ddlSeason"]/option[{}]'.format(Y)).click() # 연도
    time.sleep(1)
    # season
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeries_ddlSeries"]/option[1]').click() # Season
    time.sleep(1)
    for T in team: 
        driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
        time.sleep(1.3)
        for P in position:
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlPos_ddlPos"]/option[{}]'.format(P)).click() # 포지션별
            time.sleep(1.5)
            # 홈/방문
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituation_ddlSituation"]/option[7]').click() # 상황별 1 / 주간, 야간별
            time.sleep(1.5)
            for D in detail:
                driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail"]/option[{}]'.format(D)).click() # 상황별 2
                time.sleep(1.5)

                html = driver.page_source
                soup = BeautifulSoup(html, 'html.parser')
                data = soup.find('table', { 'class': 'tData01 tt' })
    
                # 크롤링
    
                table1 = parser_functions.make2d(data)

                df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
                if df1.empty:
                    pass
                else:
                    # print(df1)
                    df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team[T])+'_'+'{}'.format(position[P]) +'_'+ '주간야간별' +'_'+ '{}'.format(detail[D]) +'_' + '선수기록(타자).csv', encoding = 'utf-8')
# Out:
# C:\Users\nhw85\AppData\Local\Temp\ipykernel_35020\3448228063.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %% [markdown]
# 자동 저장 code

# %%
os.chdir("C://Users//nhw85//OneDrive//바탕 화면//새 폴더")
os.getcwd() # "C:\Users\nhw85\Downloads\타자\타자\2023_정규시즌_포수_한화_상대팀별_키움선수기록(타자).csv"
import shutil

file_list = os.listdir()
years = ['2017', '2018', '2019', '2020', '2021', '2022', '2023']
Categorized_team = os.listdir("C://Users//nhw85//OneDrive//바탕 화면//야구 데이터//팀별_상대별_성적//2017")
for y in years:
    for file in file_list: # "C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_내야수_주간야간별_야간_선수기록(타자).csv"
        year, title, team, pos, sub_title, type, detail = file.split('_')
        # print(year, title, team, sub_title, detail) 
        downloaded_file_loc = os.path.abspath(file)
        print(downloaded_file_loc)
        for T in Categorized_team: #"C:\Users\nhw85\OneDrive\바탕 화면\팀별_주간야간별_성적"
            if team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_주간야간별_성적//{}//{}//타자".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_주간야간별_성적//{}//{}//타자".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_주간야간별_성적//{}//{}//타자".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_주간야간별_성적//{}//{}//타자".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_주간야간별_성적//{}//{}//타자".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_주간야간별_성적//{}//{}//타자".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_주간야간별_성적//{}//{}//타자".format(y, team))

# %% [markdown]
# #### 주간, 야간별(투수)

# %%
path = "C://Users//nhw85//Downloads//chromedriver_win32 (1)//chromedriver.exe"

driver = webdriver.Chrome(path)


year = {36 : "2017", 37 : "2018", 38 : "2019", 39 : "2020", 40 : "2021", 41 : "2022", 42 : "2023"}
team = {2:"두산", 3:"롯데", 4: "삼성", 5: "키움", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
season = {1: "정규시즌", 2: "시범경기", 3: "와일드카드", 4: "준플레이오프", 5: "플레이오프", 6: "한국시리즈"}
situation = 7 # 주간, 야간별
detail = {2: "주간", 3: "야간"}



category_list = ['HitterBasic/Basic1.aspx', 'PitcherBasic/Basic1.aspx', 
                'Defense/Basic.aspx', 'Runner/Basic.aspx']

driver.get('https://www.koreabaseball.com/Record/Player/PitcherBasic/Basic1.aspx')

for Y in year:
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeason_ddlSeason"]/option[{}]'.format(Y)).click() # 연도
    time.sleep(1)
    # season
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeries_ddlSeries"]/option[1]').click() # Season
    time.sleep(1)
    for T in team: 
        driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
        time.sleep(1.3)
        # 홈/방문
        driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituation_ddlSituation"]/option[7]').click() # 상황별 1 / 주간, 야간별
        time.sleep(1.5)
        for D in detail:
            driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSituationDetail_ddlSituationDetail"]/option[{}]'.format(D)).click() # 상황별 2
            time.sleep(1.5)

            html = driver.page_source
            soup = BeautifulSoup(html, 'html.parser')
            data = soup.find('table', { 'class': 'tData01 tt' })

            # 크롤링

            table1 = parser_functions.make2d(data)

            df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
            if df1.empty:
                pass
            else:
                # print(df1)
                df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team[T])+'_'+ '주간야간별' +'_'+ '{}'.format(detail[D]) +'_' + '선수기록(투수).csv', encoding = 'utf-8')
# Out:
# C:\Users\nhw85\AppData\Local\Temp\ipykernel_23076\6146482.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %% [markdown]
# 자동 저장 code

# %%
os.chdir("C://Users//nhw85//OneDrive//바탕 화면//새 폴더")
os.getcwd() # "C:\Users\nhw85\Downloads\타자\타자\2023_정규시즌_포수_한화_상대팀별_키움선수기록(타자).csv"
import shutil

file_list = os.listdir()
years = ['2017', '2018', '2019', '2020', '2021', '2022', '2023']
Categorized_team = os.listdir("C://Users//nhw85//OneDrive//바탕 화면//야구 데이터//팀별_상대별_성적//2017")
for y in years:
    for file in file_list: # "C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_주간야간별_주간_선수기록(투수).csv"
        year, title, team, sub_title, type, detail = file.split('_')
        # print(year, title, team, sub_title, detail) 
        downloaded_file_loc = os.path.abspath(file)
        print(downloaded_file_loc)
        for T in Categorized_team: #"C:\Users\nhw85\OneDrive\바탕 화면\팀별_주간야간별_성적"
            if team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_주간야간별_성적//{}//{}//투수".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_주간야간별_성적//{}//{}//투수".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_주간야간별_성적//{}//{}//투수".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_주간야간별_성적//{}//{}//투수".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_주간야간별_성적//{}//{}//투수".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_주간야간별_성적//{}//{}//투수".format(y, team))
            elif team == T and year == y:
                shutil.move(downloaded_file_loc, "C://Users//nhw85//OneDrive//바탕 화면//팀별_주간야간별_성적//{}//{}//투수".format(y, team))
# Out:
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# ...
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2017_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2018_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2019_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2020_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2021_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2022_정규시즌_한화_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KIA_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_KT_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_LG_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_NC_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_SK_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_두산_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_롯데_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_삼성_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_키움_주간야간별_주간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_주간야간별_야간_선수기록(투수).csv
# C:\Users\nhw85\OneDrive\바탕 화면\새 폴더\2023_정규시즌_한화_주간야간별_주간_선수기록(투수).csv

# %% [markdown]
# #### 정규시즌(타자) 기본/세부

# %%
path = "C://Users//nhw85//Downloads//chromedriver_win32 (1)//chromedriver.exe"

driver = webdriver.Chrome(path)


year = {36 : "2017", 37 : "2018", 38 : "2019", 39 : "2020", 40 : "2021", 41 : "2022", 42 : "2023"}
team = {2:"두산", 3:"롯데", 4: "삼성", 5: "키움", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
season = {1: "정규시즌", 2: "시범경기", 3: "와일드카드", 4: "준플레이오프", 5: "플레이오프", 6: "한국시리즈"}
position = {2: "포수", 3: "내야수", 4: "외야수"}


category_list = ['HitterBasic/Basic1.aspx', 'PitcherBasic/Basic1.aspx', 
                'Defense/Basic.aspx', 'Runner/Basic.aspx']

driver.get('https://www.koreabaseball.com/Record/Player/HitterBasic/Detail1.aspx')

for Y in year:
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeason_ddlSeason"]/option[{}]'.format(Y)).click() # 연도
    time.sleep(1)
    # season
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeries_ddlSeries"]/option[1]').click() # Season
    time.sleep(1)
    for T in team: 
        driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
        time.sleep(1.5)

        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        data = soup.find('table', { 'class': 'tData01 tt' })

        # 크롤링

        table1 = parser_functions.make2d(data)

        df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
        if df1.empty:
            pass
        else:
            # print(df1)
            df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team[T])+'_'+ '선수세부기록(타자).csv', encoding = 'utf-8')
# Out:
# C:\Users\nhw85\AppData\Local\Temp\ipykernel_35236\3756224939.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %% [markdown]
# #### 정규시즌(투수) 기본/세부

# %%
path = "C://Users//nhw85//Downloads//chromedriver_win32 (1)//chromedriver.exe"

driver = webdriver.Chrome(path)


year = {36 : "2017", 37 : "2018", 38 : "2019", 39 : "2020", 40 : "2021", 41 : "2022", 42 : "2023"}
team = {2:"두산", 3:"롯데", 4: "삼성", 5: "키움", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
season = {1: "정규시즌", 2: "시범경기", 3: "와일드카드", 4: "준플레이오프", 5: "플레이오프", 6: "한국시리즈"}
position = {2: "포수", 3: "내야수", 4: "외야수"}


category_list = ['HitterBasic/Basic1.aspx', 'PitcherBasic/Basic1.aspx', 
                'Defense/Basic.aspx', 'Runner/Basic.aspx']

driver.get('https://www.koreabaseball.com/Record/Player/PitcherBasic/Detail1.aspx')

for Y in year:
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeason_ddlSeason"]/option[{}]'.format(Y)).click() # 연도
    time.sleep(1)
    # season
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeries_ddlSeries"]/option[1]').click() # Season
    time.sleep(1)
    for T in team: 
        driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
        time.sleep(1.5)

        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        data = soup.find('table', { 'class': 'tData01 tt' })

        # 크롤링

        table1 = parser_functions.make2d(data)

        df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
        if df1.empty:
            pass
        else:
            # print(df1)
            df1.to_csv('{}'.format(year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team[T])+'_'+ '선수세부기록(투수).csv', encoding = 'utf-8')
# Out:
# C:\Users\nhw85\AppData\Local\Temp\ipykernel_35236\4038793642.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %% [markdown]
# #### 시범경기(수비)

# %%
path = "C://Users//nhw85//Downloads//chromedriver_win32 (1)//chromedriver.exe"

driver = webdriver.Chrome(path)


year = {36 : "2017", 37 : "2018", 38 : "2019", 39 : "2020", 40 : "2021", 41 : "2022", 42 : "2023"}
team = {2:"두산", 3:"롯데", 4: "삼성", 5: "키움", 6: "한화", 7: "KIA", 8: "KT", 9: "LG", 10: "NC", 11: "SK" }
season = {1: "정규시즌", 2: "시범경기", 3: "와일드카드", 4: "준플레이오프", 5: "플레이오프", 6: "한국시리즈"}
position = {2: "포수", 3: "내야수", 4: "외야수"}
Runner_year = {17:"2017", 18:"2018", 19:'2019', 20:"2020", 21:"2021", 22:'2022', 23:"2023"}

category_list = ['HitterBasic/Basic1.aspx', 'PitcherBasic/Basic1.aspx', 
                'Defense/Basic.aspx', 'Runner/Basic.aspx']

driver.get('https://www.koreabaseball.com/Record/Player/Defense/Basic.aspx')

for Y in Runner_year:
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeason_ddlSeason"]/option[{}]'.format(Y)).click() # 연도
    time.sleep(1)
    # season
    driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlSeries_ddlSeries"]/option[1]').click() # Season
    time.sleep(1)
    for T in team: 
        driver.find_element(By.XPATH, '//*[@id="cphContents_cphContents_cphContents_ddlTeam_ddlTeam"]/option[{}]'.format(T)).click() # 팀별
        time.sleep(1.5)

        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        data = soup.find('table', { 'class': 'tData01 tt' })

        # 크롤링

        table1 = parser_functions.make2d(data)

        df1 = pd.DataFrame(data=table1[1:], columns=table1[0])
        if df1.empty:
            pass
        else:
            # print(df1)
            df1.to_csv('{}'.format(Runner_year[Y]) +'_' + "정규시즌" +'_'+'{}'.format(team[T])+'_'+ '선수수비기록(타자).csv', encoding = 'utf-8')
# Out:
# C:\Users\nhw85\AppData\Local\Temp\ipykernel_33620\2319479654.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)
